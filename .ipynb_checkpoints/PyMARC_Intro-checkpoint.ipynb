# %%
import pymarc
from pymarc import MARCReader, Record, Field, marcxml
import re

# %%
# Open the binary MARC file 'TEST.mrc' in read mode 
with open('TEST.mrc', 'rb') as fh:
    #create a MARCReader object with the file
    reader = MARCReader(fh)
    #loop through the reader object and for each record you find
    for record in reader:
        # print the title of the record
        print(record.title())
# Out:
# The stopover = Voir du pays.
# Almost adults.
# Toulouse-Lautrec
# Saute-Dry-Heat Cooking with Fat

# %%
dir(reader)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'file_handle',
#  'force_utf8',
#  'hide_utf8_warnings',
#  'to_unicode',
#  'utf8_handling']

# %%
# Let's get the first record
dir(record)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_sort_fields',
#  'add_field',
#  'add_grouped_field',
#  'add_ordered_field',
#  'addedentries',
#  'as_dict',
#  'as_json',
#  'as_marc',
#  'as_marc21',
#  'author',
#  'decode_marc',
#  'fields',
#  'force_utf8',
#  'get_fields',
#  'isbn',
#  'leader',
#  'location',
#  'notes',
#  'physicaldescription',
#  'pos',
#  'publisher',
#  'pubyear',
#  'remove_field',
#  'remove_fields',
#  'series',
#  'subjects',
#  'title',
#  'uniformtitle']

# %%
from pymarc import MARCReader, Record, Field
with open('TEST.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    rec = next(reader)

# %%
q = rec.get_fields()

# %%
dir(rec)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_sort_fields',
#  'add_field',
#  'add_grouped_field',
#  'add_ordered_field',
#  'addedentries',
#  'as_dict',
#  'as_json',
#  'as_marc',
#  'as_marc21',
#  'author',
#  'decode_marc',
#  'fields',
#  'force_utf8',
#  'get_fields',
#  'isbn',
#  'leader',
#  'location',
#  'notes',
#  'physicaldescription',
#  'pos',
#  'publisher',
#  'pubyear',
#  'remove_field',
#  'remove_fields',
#  'series',
#  'subjects',
#  'title',
#  'uniformtitle']

# %%
for f in rec.fields:
    print(f)
# Out:
# =001  kan1464136
# =003  CaSfKAN
# =005  20140324125357.0
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170712p20172016cau102\\\\\\\\o\\\vlfre\d
# =028  52$a1464136$bKanopy
# =040  \\$aUtOrKAN$beng$erda$cUtOrKAN
# =245  04$aThe stopover =$bVoir du pays.
# =246  31$aVoir du pays
# =264  \1$bFirst Run Features,$c2016.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (103 minutes):$bdigital, .flv file, sound
# =306  \\$a014213
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =344  \\$adigital
# =347  \\$avideo file$bMPEG-4$bFlash
# =500  \\$aTitle from title frames.
# =518  \\$aOriginally produced by First Run Features in 2016.
# =520  \\$aAt the end of their tour of duty in Afghanistan, two young military women, Aurore and Marine, are given three days of "decompression leave" with their unit, among tourists, at a five-star resort in Cyprus. But it's not that easy to forget the war and leave violence behind.
# =538  \\$aMode of access: World Wide Web.
# =650  \0$aFriendship.
# =650  \0$aWomen soldiers.
# =650  \0$aAfghan War, 2001-.
# =655  \7$aFeature films.$2lcgft
# =700  1\$aCoulin, Delphine,$efilm director.
# =700  1\$aCoulin, Muriel,$efilm director.
# =700  1\$aKōnstantinou, Antrea,$eactor.
# =700  1\$aLabed, Ariane,$eactor.
# =700  1\$aRoman, Ginger,$eactor.
# =700  1\$aLeklou, Karim,$eactor.
# =700  1\$aPapadimitriou, Makis,$eactor.
# =700  1\$aSoko,$d1986-$eactor.
# =710  2\$aFirst Run Features (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/464137$zA Kanopy streaming video

# %%
url = rec['856']

# %%
url.value()
# Out:
# 'http://uc.kanopystreaming.com/node/464137 A Kanopy streaming video'

# %%
#transforming a batchcave function into PyMARC
# Change =001 field to =002, and add 003
# x = re.sub('(?m)^=001 (.*)', '=002 \\1\n=003 ER-EAI-2nd', x)
# look at current values
one = rec['001']
three = rec['003']
#print(three.value())
 
#add a field
rec.add_field(Field(tag = '002',data = rec['001'].value()))

#rec.remove_field(rec.get_fields('001')[0])


#x = re.sub('(?m)^=008', r'=949  \\\\$a*b3=z;bn=buint;\n=949  \\1$luint$rs$t99\n=730      0\$aEarly American imprints (Online).$nSecond series,$pShaw-Shoemaker.$5OCU\n=506  \\$aAccess     restricted to users at subscribing institutions\n=008', x)
rec.add_field(Field(tag = '949', indicators = ['\\', '\\'], subfields = ['a', '*b3=z;bn=buint;']))
rec.add_field(Field(tag = '949', indicators = ['\\', '1'], subfields = ['l', 'uint', 'r', 's', 't', '99']))
rec.add_field(Field(tag = '730', indicators = ['0', '\\'], subfields = ['a', 'Early American imprints (Online).', 'n', 'Second series,', 'p', 'Shaw-Shoemaker.', '5', 'OCU']))
rec.add_field(Field(tag = '506', indicators = ['\\', ''], subfields = ['a', 'Access restricted to users at subscribing institutions']))

rec.remove_field(rec.get_fields('008')[0])
#x = utilities.DeleteLocGov(x)
#x = utilities.Standardize856_956(x)
#x = utilities.CharRefTrans(x)
#x = utilities.MarcEditSaveToMRK(x, filename)
#x = utilities.MarcEditMakeFile(x, filename)
#return x

print(rec)
# Out:
# =LDR  01929ngm a2200493 i 4500
# =001  kan1464136
# =003  CaSfKAN
# =005  20140324125357.0
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =028  52$a1464136$bKanopy
# =040  \\$aUtOrKAN$beng$erda$cUtOrKAN
# =245  04$aThe stopover =$bVoir du pays.
# =246  31$aVoir du pays
# =264  \1$bFirst Run Features,$c2016.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (103 minutes):$bdigital, .flv file, sound
# =306  \\$a014213
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =344  \\$adigital
# =347  \\$avideo file$bMPEG-4$bFlash
# =500  \\$aTitle from title frames.
# =518  \\$aOriginally produced by First Run Features in 2016.
# =520  \\$aAt the end of their tour of duty in Afghanistan, two young military women, Aurore and Marine, are given three days of "decompression leave" with their unit, among tourists, at a five-star resort in Cyprus. But it's not that easy to forget the war and leave violence behind.
# =538  \\$aMode of access: World Wide Web.
# =650  \0$aFriendship.
# =650  \0$aWomen soldiers.
# =650  \0$aAfghan War, 2001-.
# =655  \7$aFeature films.$2lcgft
# =700  1\$aCoulin, Delphine,$efilm director.
# =700  1\$aCoulin, Muriel,$efilm director.
# =700  1\$aKōnstantinou, Antrea,$eactor.
# =700  1\$aLabed, Ariane,$eactor.
# =700  1\$aRoman, Ginger,$eactor.
# =700  1\$aLeklou, Karim,$eactor.
# =700  1\$aPapadimitriou, Makis,$eactor.
# =700  1\$aSoko,$d1986-$eactor.
# =710  2\$aFirst Run Features (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/464137$zA Kanopy streaming video
# =002  kan1464136
# =949  \\$a*b3=z;bn=buint;
# =949  \1$luint$rs$t99
# =730  0\$aEarly American imprints (Online).$nSecond series,$pShaw-Shoemaker.$5OCU
# =506  \$aAccess restricted to users at subscribing institutions

# %%
#break records into one string separated by newline
with open('TEST.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    x = ''
    for rec in reader:
        x += str(rec) + '\n'
        
print(x)
# Out:
# =LDR  01929ngm a2200493 i 4500
# =001  kan1464136
# =003  CaSfKAN
# =005  20140324125357.0
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170712p20172016cau102\\\\\\\\o\\\vlfre\d
# =028  52$a1464136$bKanopy
# =040  \\$aUtOrKAN$beng$erda$cUtOrKAN
# =245  04$aThe stopover =$bVoir du pays.
# =246  31$aVoir du pays
# =264  \1$bFirst Run Features,$c2016.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (103 minutes):$bdigital, .flv file, sound
# =306  \\$a014213
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =344  \\$adigital
# =347  \\$avideo file$bMPEG-4$bFlash
# =500  \\$aTitle from title frames.
# =518  \\$aOriginally produced by First Run Features in 2016.
# =520  \\$aAt the end of their tour of duty in Afghanistan, two young military women, Aurore and Marine, are given three days of "decompression leave" with their unit, among tourists, at a five-star resort in Cyprus. But it's not that easy to forget the war and leave violence behind.
# =538  \\$aMode of access: World Wide Web.
# =650  \0$aFriendship.
# =650  \0$aWomen soldiers.
# =650  \0$aAfghan War, 2001-.
# =655  \7$aFeature films.$2lcgft
# =700  1\$aCoulin, Delphine,$efilm director.
# =700  1\$aCoulin, Muriel,$efilm director.
# =700  1\$aKōnstantinou, Antrea,$eactor.
# =700  1\$aLabed, Ariane,$eactor.
# =700  1\$aRoman, Ginger,$eactor.
# =700  1\$aLeklou, Karim,$eactor.
# =700  1\$aPapadimitriou, Makis,$eactor.
# =700  1\$aSoko,$d1986-$eactor.
# =710  2\$aFirst Run Features (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/464137$zA Kanopy streaming video
#
# =LDR  01778ngm a2200421 i 4500
# =001  kan1497493
# =003  CaSfKAN
# =005  20140324125357.0
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170719p20172017cau089\\\\\\\\o\\\vleng\d
# =028  52$a1497493$bKanopy
# =040  \\$aUtOrKAN$beng$erda$cUtOrKAN
# =245  00$aAlmost adults.
# =264  \1$bGravitas,$c2017.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (90 minutes):$bdigital, .flv file, sound
# =306  \\$a012955
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =344  \\$adigital
# =347  \\$avideo file$bMPEG-4$bFlash
# =500  \\$aTitle from title frames.
# =518  \\$aOriginally produced by Gravitas in 2017.
# =520  \\$aThis comedy feature follows two best friends in their final year of college while they transition into adulthood. One embraces her sexuality and tries to catch up on everything she has missed during her teenage years, while the other ends a long term relationship with her boyfriend and discovers her life isn't going as planned. Both struggle to keep their friendship together as they begin growing apart.
# =538  \\$aMode of access: World Wide Web.
# =650  \0$aFriendship.
# =650  \0$aComedy films.
# =655  \7$aFeature films.$2lcgft
# =700  1\$aRotella, Sarah,$efilm director.
# =700  1\$aBauman, Elise,$eactor.
# =700  1\$aGerhard, Justin,$eactor.
# =700  1\$aNegovanlis, Natasha,$eactor.
# =710  2\$aGravitas (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/497494$zA Kanopy streaming video
#
# =LDR  01630ngm a2200361ua 4500
# =001  kan1166011
# =003  CaSfKAN
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170721p20172010cau050\\\\\\\\o\\\vleng\d
# =028  52$a1166011$bKanopy
# =035  \\$a(OCoLC)945762855
# =040  \\$aVDU$beng$cVDU
# =245  00$aToulouse-Lautrec
# =264  \1$bArthaus Musik,$c2010.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (51 minutes):$bdigital, .flv file, sound
# =306  \\$a005006
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =500  \\$aIn Process Record.
# =500  \\$aTitle from title frames.
# =518  \\$aOriginally produced by Arthaus Musik in 2010.
# =520  \\$a  Known best for his vivid portrayals of the famous Moulin Rouge nightclub, 19th-century French painter Henri Toulouse-Lautrec had a difficult life: He was crippled by a genetic disease and died at 36 after years of alcoholism and syphilis had racked his body. This gripping program looks at Toulouse-Lautrec's life and art, and leading authorities, art historians and scholars offer analysis and commentary that provide an inside look at the artist.
# =538  \\$aMode of access: World Wide Web.
# =546  \\$aIn English
# =653  \\$aVisual Art
# =700  1\$aChadwick, Hilary,$efilmmaker
# =710  2\$aArthaus Musik (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/166012$zA Kanopy streaming video
#
# =LDR  01498ngm a2200361za 4500
# =001  kan1149871
# =003  CaSfKAN
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170724p20172012cau039\\\\\\\\o\\\vlund\d
# =028  52$a1149871$bKanopy
# =035  \\$a(OCoLC)921956686
# =040  \\$aVDU$beng$cVDU
# =245  00$aSaute-Dry-Heat Cooking with Fat
# =264  \1$bThe Great Courses,$c2012.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (40 minutes):$bdigital, .flv file, sound
# =306  \\$a003928
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =500  \\$aTitle from title frames.
# =500  \\$aIn Process Record.
# =511  0\$aFeatures: Bill Briwa
# =518  \\$aOriginally produced by The Great Courses in 2012.
# =520  \\$aBegin strengthening your cooking techniques with a close look at using the right pan, the right amount of fat, and the right temperature to make crispy and delicious sauteed foods. As you explore the ins and outs of sauteing, you learn how to make a delicious (and simple) dish: Chicken Marsala.
# =538  \\$aMode of access: World Wide Web.
# =546  \\$aIn English
# =653  \\$aFood Technology
# =710  2\$aThe Great Courses (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/149872$zA Kanopy streaming video

# %%
# convert MARCXML to MARC
with open('etd_test.xml', 'rb') as fh:
    records = marcxml.parse_xml_to_array(fh)
    
for rec in records:
    print(rec)
    
print(rec)
# Out:
# =LDR  01125npc i2200289Ki 4500
# =008  040320k19182013xx\\\\\\\\\\\\000\0\eng\d
# =040  \\$aCIN$beng$edacs$cCIN
# =099  \\$aUS-14-05
# =110  2\$aCincinnati Ballet
# =245  10$aCincinnati Ballet records,$f1918-2013$g(bulk 1964-2012).
# =264  \0$c1918-2013.
# =264  \0$c1964-2012.
# =300  \\$a41 linear feet.
# =506  \\$aThis collection is open for research.
# =520  3\$aRecords of the Cincinnati Ballet including photographs, production information, former dancer files, scrapbooks, and advertising information.
# =545  1\$aThe Cincinnati Ballet was chartered as the "Cincinnati Civic Ballet" in 1958. The company held their first auditions in 1963 and the original troupe consisted of 41 dancers. Oleg Sabline served as the first artistic director and John A. Spain was the first president of the Board of Trustees. The first performance took place at the University of Cincinnati's Wilson Auditorium in March of 1964.
# =546  \\$aThe records are in English.
# =610  20$aUniversity of Cincinnati. $bCollege-Conservatory of Music
# =650  \0$aBallet$zOhio$zCincinnati
# =650  \0$aDance history
# =650  \0$aDance schools$zOhio$zCincinnati
# =852  \\$aUniversity of Cincinnati.$bArchives and Rare Book Library
# =856  40$uhttp://rave.ohiolink.edu/archives/ead/OhCiUAR0430$zConnect to finding aid online
#
# =LDR  01125npc i2200289Ki 4500
# =008  040320k19182013xx\\\\\\\\\\\\000\0\eng\d
# =040  \\$aCIN$beng$edacs$cCIN
# =099  \\$aUS-14-05
# =110  2\$aCincinnati Ballet
# =245  10$aCincinnati Ballet records,$f1918-2013$g(bulk 1964-2012).
# =264  \0$c1918-2013.
# =264  \0$c1964-2012.
# =300  \\$a41 linear feet.
# =506  \\$aThis collection is open for research.
# =520  3\$aRecords of the Cincinnati Ballet including photographs, production information, former dancer files, scrapbooks, and advertising information.
# =545  1\$aThe Cincinnati Ballet was chartered as the "Cincinnati Civic Ballet" in 1958. The company held their first auditions in 1963 and the original troupe consisted of 41 dancers. Oleg Sabline served as the first artistic director and John A. Spain was the first president of the Board of Trustees. The first performance took place at the University of Cincinnati's Wilson Auditorium in March of 1964.
# =546  \\$aThe records are in English.
# =610  20$aUniversity of Cincinnati. $bCollege-Conservatory of Music
# =650  \0$aBallet$zOhio$zCincinnati
# =650  \0$aDance history
# =650  \0$aDance schools$zOhio$zCincinnati
# =852  \\$aUniversity of Cincinnati.$bArchives and Rare Book Library
# =856  40$uhttp://rave.ohiolink.edu/archives/ead/OhCiUAR0430$zConnect to finding aid online

# %%
with open('TEST.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    recs = Record()
    for r in reader:
        print(dir(r))
        print(r.as_marc())
# Out:
# ['__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_sort_fields', 'add_field', 'add_grouped_field', 'add_ordered_field', 'addedentries', 'as_dict', 'as_json', 'as_marc', 'as_marc21', 'author', 'decode_marc', 'fields', 'force_utf8', 'get_fields', 'isbn', 'leader', 'location', 'notes', 'physicaldescription', 'pos', 'publisher', 'pubyear', 'remove_field', 'remove_fields', 'series', 'subjects', 'title', 'uniformtitle']
# b'01929ngm a2200493 i ...\x1ekan1464136\x1eCaSfKAN\x1e20140324125357.0\x1em     o  c        \x1evz uzazuu\x1ecr una---unuuu\x1e170712p20172016cau102        o   vlfre d\x1e52\x1fa1464136\x1fbKanopy\x1e  \x1faUtOrKAN\x1fbeng\x1ferda\x1fcUtOrKAN\x1e04\x1faThe stopover =\x1fbVoir du pays.\x1e31\x1faVoir du pays\x1e 1\x1fbFirst Run Features,\x1fc2016.\x1e 1\x1fa[San Francisco, California, USA] :\x1fbKanopy Streaming,\x1fc2017.\x1e  \x1fa1 online resource (streaming video file) (103 minutes):\x1fbdigital, .flv file, sound\x1e  \x1fa014213\x1e  \x1fatwo-dimensional moving image\x1fbtdi\x1f2rdacontent\x1e  \x1facomputer\x1fbc\x1f2rdamedia\x1e  \x1faonline resource\x1fbcr\x1f2rdacarrier\x1e  \x1fadigital\x1e  \x1favideo file\x1fbMPEG-4\x1fbFlash\x1e  \x1faTitle from title frames.\x1e  \x1faOriginally produced by First Run Features in 2016.\x1e  \x1faAt the end of their tour of duty in Afghanistan, two young military women, Aurore and Marine, are given three days of "decompression leave" with their unit, among tourists, at a five-star resort in Cyprus. But it\'s not that easy to forget the war and leave violence behind.\x1e  \x1faMode of access: World Wide Web.\x1e 0\x1faFriendship.\x1e 0\x1faWomen soldiers.\x1e 0\x1faAfghan War, 2001-.\x1e 7\x1faFeature films.\x1f2lcgft\x1e1 \x1faCoulin, Delphine,\x1fefilm director.\x1e1 \x1faCoulin, Muriel,\x1fefilm director.\x1e1 \x1faK\xc5\x8dnstantinou, Antrea,\x1feactor.\x1e1 \x1faLabed, Ariane,\x1feactor.\x1e1 \x1faRoman, Ginger,\x1feactor.\x1e1 \x1faLeklou, Karim,\x1feactor.\x1e1 \x1faPapadimitriou, Makis,\x1feactor.\x1e1 \x1faSoko,\x1fd1986-\x1feactor.\x1e2 \x1faFirst Run Features (Firm),\x1f4dst\x1e2 \x1faKanopy (Firm),\x1f4dst\x1e40\x1fuhttp://uc.kanopystreaming.com/node/464137\x1fzA Kanopy streaming video\x1e\x1d'
# ['__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_sort_fields', 'add_field', 'add_grouped_field', 'add_ordered_field', 'addedentries', 'as_dict', 'as_json', 'as_marc', 'as_marc21', 'author', 'decode_marc', 'fields', 'force_utf8', 'get_fields', 'isbn', 'leader', 'location', 'notes', 'physicaldescription', 'pos', 'publisher', 'pubyear', 'remove_field', 'remove_fields', 'series', 'subjects', 'title', 'uniformtitle']
# b"01778ngm a2200421 i ...\x1ekan1497493\x1eCaSfKAN\x1e20140324125357.0\x1em     o  c        \x1evz uzazuu\x1ecr una---unuuu\x1e170719p20172017cau089        o   vleng d\x1e52\x1fa1497493\x1fbKanopy\x1e  \x1faUtOrKAN\x1fbeng\x1ferda\x1fcUtOrKAN\x1e00\x1faAlmost adults.\x1e 1\x1fbGravitas,\x1fc2017.\x1e 1\x1fa[San Francisco, California, USA] :\x1fbKanopy Streaming,\x1fc2017.\x1e  \x1fa1 online resource (streaming video file) (90 minutes):\x1fbdigital, .flv file, sound\x1e  \x1fa012955\x1e  \x1fatwo-dimensional moving image\x1fbtdi\x1f2rdacontent\x1e  \x1facomputer\x1fbc\x1f2rdamedia\x1e  \x1faonline resource\x1fbcr\x1f2rdacarrier\x1e  \x1fadigital\x1e  \x1favideo file\x1fbMPEG-4\x1fbFlash\x1e  \x1faTitle from title frames.\x1e  \x1faOriginally produced by Gravitas in 2017.\x1e  \x1faThis comedy feature follows two best friends in their final year of college while they transition into adulthood. One embraces her sexuality and tries to catch up on everything she has missed during her teenage years, while the other ends a long term relationship with her boyfriend and discovers her life isn't going as planned. Both struggle to keep their friendship together as they begin growing apart.\x1e  \x1faMode of access: World Wide Web.\x1e 0\x1faFriendship.\x1e 0\x1faComedy films.\x1e 7\x1faFeature films.\x1f2lcgft\x1e1 \x1faRotella, Sarah,\x1fefilm director.\x1e1 \x1faBauman, Elise,\x1feactor.\x1e1 \x1faGerhard, Justin,\x1feactor.\x1e1 \x1faNegovanlis, Natasha,\x1feactor.\x1e2 \x1faGravitas (Firm),\x1f4dst\x1e2 \x1faKanopy (Firm),\x1f4dst\x1e40\x1fuhttp://uc.kanopystreaming.com/node/497494\x1fzA Kanopy streaming video\x1e\x1d"
# ['__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_sort_fields', 'add_field', 'add_grouped_field', 'add_ordered_field', 'addedentries', 'as_dict', 'as_json', 'as_marc', 'as_marc21', 'author', 'decode_marc', 'fields', 'force_utf8', 'get_fields', 'isbn', 'leader', 'location', 'notes', 'physicaldescription', 'pos', 'publisher', 'pubyear', 'remove_field', 'remove_fields', 'series', 'subjects', 'title', 'uniformtitle']
# b"01630ngm a2200361ua \x1ekan1166011\x1eCaSfKAN\x1em     o  c        \x1evz uzazuu\x1ecr una---unuuu\x1e170721p20172010cau050        o   vleng d\x1e52\x1fa1166011\x1fbKanopy\x1e  \x1fa(OCoLC)945762855\x1e  \x1faVDU\x1fbeng\x1fcVDU\x1e00\x1faToulouse-Lautrec\x1e 1\x1fbArthaus Musik,\x1fc2010.\x1e 1\x1fa[San Francisco, California, USA] :\x1fbKanopy Streaming,\x1fc2017.\x1e  \x1fa1 online resource (streaming video file) (51 minutes):\x1fbdigital, .flv file, sound\x1e  \x1fa005006\x1e  \x1fatwo-dimensional moving image\x1fbtdi\x1f2rdacontent\x1e  \x1facomputer\x1fbc\x1f2rdamedia\x1e  \x1faonline resource\x1fbcr\x1f2rdacarrier\x1e  \x1faIn Process Record.\x1e  \x1faTitle from title frames.\x1e  \x1faOriginally produced by Arthaus Musik in 2010.\x1e  \x1fa  Known best for his vivid portrayals of the famous Moulin Rouge nightclub, 19th-century French painter Henri Toulouse-Lautrec had a difficult life: He was crippled by a genetic disease and died at 36 after years of alcoholism and syphilis had racked his body. This gripping program looks at Toulouse-Lautrec's life and art, and leading authorities, art historians and scholars offer analysis and commentary that provide an inside look at the artist.\x1e  \x1faMode of access: World Wide Web.\x1e  \x1faIn English\x1e  \x1faVisual Art\x1e1 \x1faChadwick, Hilary,\x1fefilmmaker \x1e2 \x1faArthaus Musik (Firm),\x1f4dst\x1e2 \x1faKanopy (Firm),\x1f4dst\x1e40\x1fuhttp://uc.kanopystreaming.com/node/166012\x1fzA Kanopy streaming video\x1e\x1d"
# ['__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_sort_fields', 'add_field', 'add_grouped_field', 'add_ordered_field', 'addedentries', 'as_dict', 'as_json', 'as_marc', 'as_marc21', 'author', 'decode_marc', 'fields', 'force_utf8', 'get_fields', 'isbn', 'leader', 'location', 'notes', 'physicaldescription', 'pos', 'publisher', 'pubyear', 'remove_field', 'remove_fields', 'series', 'subjects', 'title', 'uniformtitle']
# b'01498ngm a2200361za \x1ekan1149871\x1eCaSfKAN\x1em     o  c        \x1evz uzazuu\x1ecr una---unuuu\x1e170724p20172012cau039        o   vlund d\x1e52\x1fa1149871\x1fbKanopy\x1e  \x1fa(OCoLC)921956686\x1e  \x1faVDU\x1fbeng\x1fcVDU\x1e00\x1faSaute-Dry-Heat Cooking with Fat\x1e 1\x1fbThe Great Courses,\x1fc2012.\x1e 1\x1fa[San Francisco, California, USA] :\x1fbKanopy Streaming,\x1fc2017.\x1e  \x1fa1 online resource (streaming video file) (40 minutes):\x1fbdigital, .flv file, sound\x1e  \x1fa003928\x1e  \x1fatwo-dimensional moving image\x1fbtdi\x1f2rdacontent\x1e  \x1facomputer\x1fbc\x1f2rdamedia\x1e  \x1faonline resource\x1fbcr\x1f2rdacarrier\x1e  \x1faTitle from title frames.\x1e  \x1faIn Process Record.\x1e0 \x1faFeatures: Bill Briwa\x1e  \x1faOriginally produced by The Great Courses in 2012.\x1e  \x1faBegin strengthening your cooking techniques with a close look at using the right pan, the right amount of fat, and the right temperature to make crispy and delicious sauteed foods. As you explore the ins and outs of sauteing, you learn how to make a delicious (and simple) dish: Chicken Marsala.\x1e  \x1faMode of access: World Wide Web.\x1e  \x1faIn English\x1e  \x1faFood Technology\x1e2 \x1faThe Great Courses (Firm),\x1f4dst\x1e2 \x1faKanopy (Firm),\x1f4dst\x1e40\x1fuhttp://uc.kanopystreaming.com/node/149872\x1fzA Kanopy streaming video\x1e\x1d'

# %%
# function for seek and destroy
def DeleteLocGov(rec):
    if rec['856'] is not None:
        url = rec['856'].value()
        if re.search(r'.*loc.gov*', url):
            print("gov")
            
        elif re.search(r'.*kano*', url):
            print("it's kanopy!")
            
        else:
            print("no luck")

    return rec
        
with open('TEST.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    for r in reader:
        r = DeleteLocGov(r)
# Out:
# it's kanopy!
# it's kanopy!
# it's kanopy!
# it's kanopy!

# %%
url = "https://kanopystreaming.com....blahblahblah"
pattern = re.compile(r'kano')
q = re.search(pattern, url)
print(q)
# Out:
# <_sre.SRE_Match object; span=(8, 12), match='kano'>

# %%
#Standardize a URL

def CleanURL(url):
    #delete all occurrences of $2
    print(dir(url))
    url.delete_subfield('2')
    #delete all $z
    url.delete_subfield('z')
    #add standard $z
    url.add_subfield('z', 'Connect to resource online')
    #delete all $q
    url.delete_subfield('q')
    #delete all $y
    url.delete_subfield('y')
    #move leading $3 to EOF
    #
    return url
    
def Standardize856_956(*args):
    rec = args[0]
    if rec['856'] is not None:
        print(rec['856'].subfields)
        field856 = rec['856'] 
        if rec['856'].indicator1 != '4':
            print('Found URL field with unexpected indicator')
        print(field856)
        print(rec['856'].indicators)
        clean856 = CleanURL(field856)
        print(clean856)

        
    if rec['956'] is not None:
        if rec['956'].indicator1 != '4':
            print('Found URL field with unexpected indicator')
        print(rec['956'])
    
    
    #TODO implement  if len(args) > 1 and type(args[1]) == str:
    #if re.search('\$3', line):
    # line = re.sub('(\$3)(.*)', '\\1{0} (\\2)'.format(args[1]), line)
    if len(args) > 1 and type(args[1]) == str:
        rec['856'].add_subfield('3', args[1])
    
    # else:
    # line = line + '$3{0} :'.format(args[1])

    return rec

with open('TEST.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    for r in reader:
        rec = r
        
print(Standardize856_956(rec, 'Readex'))
# Out:
# ['u', 'http://uc.kanopystreaming.com/node/149872', 'z', 'A Kanopy streaming video']
# =856  40$uhttp://uc.kanopystreaming.com/node/149872$zA Kanopy streaming video
# ['4', '0']
# ['_Field__pos', '__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'add_subfield', 'as_marc', 'as_marc21', 'delete_subfield', 'format_field', 'get_subfields', 'indicator1', 'indicator2', 'indicators', 'is_control_field', 'is_subject_field', 'subfields', 'tag', 'value']
# =856  40$uhttp://uc.kanopystreaming.com/node/149872$zConnect to resource online
# =LDR  01498ngm a2200361za 4500
# =001  kan1149871
# =003  CaSfKAN
# =006  m\\\\\o\\c\\\\\\\\
# =007  vz\uzazuu
# =007  cr\una---unuuu
# =008  170724p20172012cau039\\\\\\\\o\\\vlund\d
# =028  52$a1149871$bKanopy
# =035  \\$a(OCoLC)921956686
# =040  \\$aVDU$beng$cVDU
# =245  00$aSaute-Dry-Heat Cooking with Fat
# =264  \1$bThe Great Courses,$c2012.
# =264  \1$a[San Francisco, California, USA] :$bKanopy Streaming,$c2017.
# =300  \\$a1 online resource (streaming video file) (40 minutes):$bdigital, .flv file, sound
# =306  \\$a003928
# =336  \\$atwo-dimensional moving image$btdi$2rdacontent
# =337  \\$acomputer$bc$2rdamedia
# =338  \\$aonline resource$bcr$2rdacarrier
# =500  \\$aTitle from title frames.
# =500  \\$aIn Process Record.
# =511  0\$aFeatures: Bill Briwa
# =518  \\$aOriginally produced by The Great Courses in 2012.
# =520  \\$aBegin strengthening your cooking techniques with a close look at using the right pan, the right amount of fat, and the right temperature to make crispy and delicious sauteed foods. As you explore the ins and outs of sauteing, you learn how to make a delicious (and simple) dish: Chicken Marsala.
# =538  \\$aMode of access: World Wide Web.
# =546  \\$aIn English
# =653  \\$aFood Technology
# =710  2\$aThe Great Courses (Firm),$4dst
# =710  2\$aKanopy (Firm),$4dst
# =856  40$uhttp://uc.kanopystreaming.com/node/149872$zConnect to resource online$3Readex
